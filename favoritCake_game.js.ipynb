// %%
var user = prompt("do you like to eat a cakes?").toUpperCase();

switch(user){
    case 'YES':
        var favoritCake = prompt("what is your favorit cake?").toUpperCase();
        switch(favoritCake){
            case 'LEMON':
                var cake1 = prompt("lemon").toUpperCase();
                if(favoritCake === 'LEMON'){
                    console.log("that is also my favorit cake!");
                    }
                else {
                    console.log("what other kind cake do you like?");        
                    }
        var when = prompt("any time during the year?").toUpperCase();    
        var place = prompt("only when at home?").toUpperCase();
        if(when === 'YES' || place === 'NO'){
            console.log("you really love lemon cake!")
            }
        else{
            console.log("i thought you liked lemon cake.");
            }
        break;
    
    case 'NO':
        console.log("i hate it!");
        break;
    
    case 'Some times':
        var otherCakes = prompt("you prefer other cakes").toUpperCase();
        var money = prompt("when i do not have the money").toUpperCase();
        if(otherCakes === 'YES' && moeny === 'YES'){
            console.log("you actually do love lemon cake!");
            }
        else{
            console.log("so if money is there you love yourself some lemon cake huh.");
            }
        break;
        
            case 'NUTS':
                var cake2 = prompt("nuts").toUpperCase();
                if(favoritCake === 'NUTS'){
                    console.log("i like dry cakes like that!");
                    }
                else {
                    console.log("what other kind cake do you like?");        
                    }
        var when = prompt("any time during the year?").toUpperCase();    
        var place = prompt("only when at home?").toUpperCase();
        if(when === 'YES' || place === 'NO'){
            console.log("you love cakes with nuts!")
            }
        else{
            console.log("i thought you liked cakes with nuts.");
            }
        break;
    
    case 'NO':
        console.log("i hate it!");
        break;
    
    case 'Some times':
        var otherCakes = prompt("you prefer other cakes").toUpperCase();
        var money = prompt("when i do not have the money").toUpperCase();
        if(otherCakes === 'YES' && moeny === 'YES'){
            console.log("you actually do love cakes with nuts!");
            }
        else{
            console.log("so if money is there you love yourself some cake with nuts huh.");
            }
        break;
        
            case 'FRUITY':
                var cake3 = prompt("fruity").toUpperCase();
                if(favoritCake === 'FRUITY'){
                    console.log("YUMMY!");
                    }
                else {
                    console.log("what other kind cake do you like?");        
                    }        
        var when = prompt("any time during the year?").toUpperCase();    
        var place = prompt("only when at home?").toUpperCase();
        if(when === 'YES' || place === 'NO'){
            console.log("you really love fruity cakes huh!")
            }
        else{
            console.log("i thought you liked fruity cakes.");
            }
        break;
    
    case 'NO':
        console.log("i hate it!");
        break;
    
    case 'Some times':
        var otherCakes = prompt("you prefer other cakes").toUpperCase();
        var money = prompt("when i do not have the money").toUpperCase();
        if(otherCakes === 'YES' && moeny === 'YES'){
            console.log("you actually do love cakes with fruits!");
            }
        else{
            console.log("so if money is there you love yourself some fruity cake huh.");
            }
        break;
    
    default:
        console.log("you have never heard of any kind of cake before?wow!");
            
            }      
        
    }
